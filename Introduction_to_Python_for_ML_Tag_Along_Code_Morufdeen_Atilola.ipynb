# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline


from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
food_data = pd.read_csv("/content/drive/My Drive/Hamoye Internship/FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding = "latin-1")

# %%
food_data.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
my_tuppy = (1,2,5,8)

my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-ce1543b3be47> in <cell line: 3>()
#       1 my_tuppy = (1,2,5,8)
#       2
# ----> 3 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
food_data[["Y2017", "Area"]].groupby("Area").sum().sort_values(by = "Y2017").head(7)
# Out:
#                           Y2017
# Area
# Sudan (former)             0.00
# Ethiopia PDR               0.00
# Comoros                   59.84
# Seychelles               442.34
# Sao Tome and Principe  12662.63
# Cabo Verde             14650.74
# Guinea-Bissau          19102.77

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

col = ['Age','Nationality','Overall']

df = pd.DataFrame(lst, columns = col, index = [1,2,3])

df
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
food_data.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
food_data.corr()
# Out:
# <ipython-input-88-80ed25308dbf>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   food_data.corr()
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# ...

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]

x = y[1][1]
x
# Out:
# 8

# %%
food_data[["Y2017", "Area"]].groupby("Area").sum().sort_values(by = "Y2017", ascending = False).head(1)
# Out:
#               Y2017
# Area
# Nigeria  1483268.23

# %%
food_data[["Item", "Y2015", "Y2018"]].groupby("Item").sum().loc["Wine"]
# Out:
# Y2015    4251.81
# Y2018    4039.32
# Name: Wine, dtype: float64

# %%
food_data.Y2014.isnull().sum()
# Out:
# 1589

# %%
food_data.Y2014.isnull().sum() * 100/food_data.Y2014.shape[0]
# Out:
# 2.6073544131401474

# %%
food_data.groupby("Element").sum().loc["Stock Variation"]
# Out:
# <ipython-input-94-3bded8ae410e>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   food_data.groupby("Element").sum().loc["Stock Variation"]
# Area Code         571566.00
# Item Code       11329527.00
# Element Code    21464704.00
# Y2014              58749.83
# Y2015              34910.99
# Y2016              33140.12
# Y2017              54316.91
# Y2018              20577.91
# Name: Stock Variation, dtype: float64

# %%
food_data.Y2017.describe()
# Out:
# count     59437.000000
# mean        140.917765
# std        1671.862359
# min       -1582.000000
# 25%           0.000000
# 50%           0.100000
# 75%           9.000000
# max      190873.000000
# Name: Y2017, dtype: float64

# %%
food_data.groupby("Element").sum().at["Processing", "Y2017"]
# Out:
# <ipython-input-96-63fd33dfd135>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   food_data.groupby("Element").sum().at["Processing", "Y2017"]
# 292836.0

# %%
food_data.Area.nunique()
# Out:
# 49

# %%
array  = np.array([[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])

array[:2, 1:]
# Out:
# array([[89, 63],
#        [92, 48]])

# %%
food_data[["Area", "Y2015", "Element"]].groupby(["Element", "Area"]).sum().loc['Protein supply quantity (g/capita/day)', "Madagascar"]
# Out:
# Y2015    173.05
# Name: (Protein supply quantity (g/capita/day), Madagascar), dtype: float64
